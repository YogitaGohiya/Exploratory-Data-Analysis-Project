# %% [markdown]
# ## Exploratory Data Analysis - Laptops Pricing dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
# %matplotlib inline

# %%
filepath="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-Coursera/laptop_pricing_dataset_mod2.csv"

# %%
df= pd.read_csv(filepath, header=0)
df.head(5)
# Out:
#    Unnamed: 0  Unnamed: 0.1 Manufacturer  Category  GPU  OS  CPU_core  \
# 0           0             0         Acer         4    2   1         5
# 1           1             1         Dell         3    1   1         3
# 2           2             2         Dell         3    1   1         7
# 3           3             3         Dell         4    2   1         5
# 4           4             4           HP         4    2   1         7
#
#    Screen_Size_inch  CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_pounds  \
# 0              14.0       0.551724       8             256        3.52800
# 1              15.6       0.689655       4             256        4.85100
# 2              15.6       0.931034       8             256        4.85100
# 3              13.3       0.551724       8             128        2.69010
# 4              15.6       0.620690       8             256        4.21155
#
#    Price Price-binned  Screen-Full_HD  Screen-IPS_panel
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0            int64
# Unnamed: 0.1          int64
# Manufacturer         object
# Category              int64
# GPU                   int64
# OS                    int64
# CPU_core              int64
# Screen_Size_inch    float64
# CPU_frequency       float64
# RAM_GB                int64
# Storage_GB_SSD        int64
# Weight_pounds       float64
# Price                 int64
# Price-binned         object
# Screen-Full_HD        int64
# Screen-IPS_panel      int64
# dtype: object

# %% [markdown]
# #### Continuous valued features
#
# Generate regression plots for each of the parameters "CPU_frequency", "Screen_Size_inch" and "Weight_pounds" against "Price". Also, print the value of correlation of each feature with "Price".

# %%
sns.regplot( x='CPU_frequency', y='Price', data = df)
plt.ylim(0,)
# Out:
# (0.0, 3974.15)

# %%
sns.regplot( x='Screen_Size_inch', y='Price', data = df)
plt.ylim(0,)
# Out:
# (0.0, 3974.15)

# %%
sns.regplot( x='Weight_pounds', y='Price', data = df)
plt.ylim(0,)
# Out:
# (0.0, 3974.15)

# %%
df[["CPU_frequency", "Screen_Size_inch", "Weight_pounds" , "Price"]].corr()
# Out:
#                   CPU_frequency  Screen_Size_inch  Weight_pounds     Price
# CPU_frequency          1.000000         -0.000948       0.066522  0.366666
# Screen_Size_inch      -0.000948          1.000000       0.797534 -0.110644
# Weight_pounds          0.066522          0.797534       1.000000 -0.050312
# Price                  0.366666         -0.110644      -0.050312  1.000000

# %%
for param in ["CPU_frequency", "Screen_Size_inch","Weight_pounds"]:
    print(f"Correlation of Price and {param} is ", df[[param,"Price"]].corr())
# Out:
# Correlation of Price and CPU_frequency is                 CPU_frequency     Price
# CPU_frequency       1.000000  0.366666
# Price               0.366666  1.000000
# Correlation of Price and Screen_Size_inch is                    Screen_Size_inch     Price
# Screen_Size_inch          1.000000 -0.110644
# Price                    -0.110644  1.000000
# Correlation of Price and Weight_pounds is                 Weight_pounds     Price
# Weight_pounds       1.000000 -0.050312
# Price              -0.050312  1.000000

# %% [markdown]
# CPU_frequency" has a 36% positive correlation with the price of the laptops. The other two parameters have weak correlation with price

# %% [markdown]
# #### categorical features
# Generate Box plots for the different feature that hold categorical values. These features would be "Category", "GPU", "OS", "CPU_core", "RAM_GB", "Storage_GB_SSD"

# %%
sns.boxplot(x='Category' , y= 'Price' ,data = df)
# Out:
# <Axes: xlabel='Category', ylabel='Price'>

# %%
sns.boxplot(x='GPU' , y= 'Price' ,data = df)
# Out:
# <Axes: xlabel='GPU', ylabel='Price'>

# %%
sns.boxplot(x='OS' , y= 'Price' ,data = df)
# Out:
# <Axes: xlabel='OS', ylabel='Price'>

# %%
sns.boxplot(x='CPU_core' , y= 'Price' ,data = df)
# Out:
# <Axes: xlabel='CPU_core', ylabel='Price'>

# %%
sns.boxplot(x='RAM_GB' , y= 'Price' ,data = df)
# Out:
# <Axes: xlabel='RAM_GB', ylabel='Price'>

# %%
sns.boxplot(x='Storage_GB_SSD' , y= 'Price' ,data = df)
# Out:
# <Axes: xlabel='Storage_GB_SSD', ylabel='Price'>

# %% [markdown]
# ### Task 2 - Descriptive Statistical Analysis
# Generate the statistical description of all the features being used in the data set. Include "object" data types as well.

# %%
df.describe()
# Out:
#        Unnamed: 0  Unnamed: 0.1    Category         GPU          OS  \
# count  238.000000    238.000000  238.000000  238.000000  238.000000
# mean   118.500000    118.500000    3.205882    2.151261    1.058824
# std     68.848868     68.848868    0.776533    0.638282    0.235790
# min      0.000000      0.000000    1.000000    1.000000    1.000000
# 25%     59.250000     59.250000    3.000000    2.000000    1.000000
# 50%    118.500000    118.500000    3.000000    2.000000    1.000000
# 75%    177.750000    177.750000    4.000000    3.000000    1.000000
# max    237.000000    237.000000    5.000000    3.000000    2.000000
#
#          CPU_core  Screen_Size_inch  CPU_frequency      RAM_GB  \
# count  238.000000        238.000000     238.000000  238.000000
# mean     5.630252         14.688655       0.813822    7.882353
# std      1.241787          1.166045       0.141860    2.482603
# min      3.000000         12.000000       0.413793    4.000000
# ...

# %%
df.describe(include=[object])
# Out:
#        Manufacturer Price-binned
# count           238          238
# unique           11            3
# top            Dell          Low
# freq             71          160

# %% [markdown]
# ### Task 3 - GroupBy and Pivot Tables
# Group the parameters "GPU", "CPU_core" and "Price" to make a pivot table and visualize this connection using the pcolor plot.

# %%
df_group1 = df[["GPU", "CPU_core","Price"]]
group_test1 = df_group1.groupby(['GPU','CPU_core'], as_index= False ).mean()
group_test1
# Out:
#    GPU  CPU_core        Price
# 0    1         3   769.250000
# 1    1         5   998.500000
# 2    1         7  1167.941176
# 3    2         3   785.076923
# 4    2         5  1462.197674
# 5    2         7  1744.621622
# 6    3         3   784.000000
# 7    3         5  1220.680000
# 8    3         7  1945.097561

# %%
group_pivot1 = group_test1.pivot(index='GPU',columns='CPU_core')
group_pivot1
# Out:
#                Price
# CPU_core           3            5            7
# GPU
# 1         769.250000   998.500000  1167.941176
# 2         785.076923  1462.197674  1744.621622
# 3         784.000000  1220.680000  1945.097561

# %%
fig, ax = plt.subplots()
im = ax.pcolor(group_pivot1, cmap='RdBu')

#label names
row_labels = group_pivot1.columns.levels[1]
col_labels = group_pivot1.index

#move ticks and labels to the center
ax.set_xticks(np.arange(group_pivot1.shape[1]) + 0.5, minor=False)
ax.set_yticks(np.arange(group_pivot1.shape[0]) + 0.5, minor=False)

#insert labels
ax.set_xticklabels(row_labels, minor=False)
ax.set_yticklabels(col_labels, minor=False)

fig.colorbar(im)

# %% [markdown]
# ### Task 4 - Pearson Correlation and p-values

# %%
from scipy import stats

# %%
for param in ['RAM_GB','CPU_frequency','Storage_GB_SSD','Screen_Size_inch','Weight_pounds','CPU_core','OS','GPU','Category']:
    pearson_coef, p_value = stats.pearsonr(df[param], df['Price'])
    print(param)
    print("The Pearson Correlation Coefficient for ",param," is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# RAM_GB
# The Pearson Correlation Coefficient for  RAM_GB  is 0.5492972971857841  with a P-value of P = 3.6815606288438424e-20
# CPU_frequency
# The Pearson Correlation Coefficient for  CPU_frequency  is 0.36666555892588604  with a P-value of P = 5.5024633507147195e-09
# Storage_GB_SSD
# The Pearson Correlation Coefficient for  Storage_GB_SSD  is 0.2434207552181029  with a P-value of P = 0.00014898923191727792
# Screen_Size_inch
# The Pearson Correlation Coefficient for  Screen_Size_inch  is -0.11064420817118269  with a P-value of P = 0.08853397846832801
# Weight_pounds
# The Pearson Correlation Coefficient for  Weight_pounds  is -0.05031225837751549  with a P-value of P = 0.4397693853434994
# CPU_core
# The Pearson Correlation Coefficient for  CPU_core  is 0.45939777733551157  with a P-value of P = 7.912950127011088e-14
# OS
# The Pearson Correlation Coefficient for  OS  is -0.2217298011482738  with a P-value of P = 0.0005696642559248033
# GPU
# ...

# %% [markdown]
# - RAM_GB and CPU_core show the strongest positive correlations with price — more RAM and more CPU cores → higher prices.
#
# - Screen size and weight show very little correlation and are not statistically significant in this data.
#
# - OS has a weak negative correlation, possibly reflecting cheaper devices using less costly OS types.
#
# - GPU and Category have weak but significant positive correlations — likely due to premium categories or gaming GPUs.
